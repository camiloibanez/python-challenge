# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
employee_df = pd.read_csv("PyBoss/reordered_employee_data.csv")
employee_df.head()
# Out:
#    Emp ID First Name  Last Name         DOB          SSN State
# 0     232       John    Mathews  02/24/1991  ***-**-9165    ND
# 1     533     Nathan      Moore  11/19/1978  ***-**-7469    ME
# 2     256     Amanda    Douglas  01/08/1990  ***-**-6961    ID
# 3     189    Heather    Andrews  08/11/1976  ***-**-1797    VT
# 4     284     Daniel  Hernandez  07/22/1976  ***-**-7473    CO

# %%
groupby_state_employee_df = employee_df.groupby("State").count()
groupby_state_employee_df.head()
# Out:
#        Emp ID  First Name  Last Name  DOB  SSN
# State
# AK         14          14         14   14   14
# AL         13          13         13   13   13
# AR         15          15         15   15   15
# AZ          9           9          9    9    9
# CA         18          18         18   18   18

# %%
groupby_state_employee_df.plot(kind="bar", y="Emp ID", figsize=(22,9), title="Employee Count by State")
plt.xlabel("State")
plt.ylabel("Number of Employees")
# Out:
# Text(0, 0.5, 'Number of Employees')

# %%
ages = []
birth_months = []

for i in np.arange(0, len(employee_df)):
    date = datetime.strptime(employee_df.loc[i,["DOB"]][0], "%m/%d/%Y")
    year_of_birth = date.strftime("%Y")
    this_year = datetime.today().strftime("%Y")
    age = int(this_year) - int(year_of_birth)
    ages.append(age)
    birth_month = date.strftime("%m")
    birth_months.append(birth_month)

# %%
employee_df["Age"] = ages
employee_df["Birth Month"] = birth_months
employee_df.head()
# Out:
#    Emp ID First Name  Last Name         DOB          SSN State  Age  \
# 0     232       John    Mathews  02/24/1991  ***-**-9165    ND   29
# 1     533     Nathan      Moore  11/19/1978  ***-**-7469    ME   42
# 2     256     Amanda    Douglas  01/08/1990  ***-**-6961    ID   30
# 3     189    Heather    Andrews  08/11/1976  ***-**-1797    VT   44
# 4     284     Daniel  Hernandez  07/22/1976  ***-**-7473    CO   44
#
#   Birth Month
# 0          02
# 1          11
# 2          01
# 3          08
# 4          07

# %%
groupby_age_employee_df = employee_df.groupby("Age").count()
groupby_age_employee_df.head()
# Out:
#      Emp ID  First Name  Last Name  DOB  SSN  State  Birthday
# Age
# 25        1           1          1    1    1      1         1
# 26       22          22         22   22   22     22        22
# 27       25          25         25   25   25     25        25
# 28       20          20         20   20   20     20        20
# 29       31          31         31   31   31     31        31

# %%
groupby_age_employee_df.plot(kind="bar", y="Emp ID", figsize=(6,4), title="Employee Count by Age")
plt.xlabel("Age")
plt.ylabel("Number of Employees")
# Out:
# Text(0, 0.5, 'Number of Employees')

# %%
groupby_birthday_employee_df = employee_df.groupby("Birth Month").count()
groupby_birthday_employee_df = groupby_birthday_employee_df.sort_values(by="Birth Month")
groupby_birthday_employee_df.head(12)
# Out:
#              Emp ID  First Name  Last Name  DOB  SSN  State  Age
# Birth Month
# 01               64          64         64   64   64     64   64
# 02               51          51         51   51   51     51   51
# 03               57          57         57   57   57     57   57
# 04               63          63         63   63   63     63   63
# 05               44          44         44   44   44     44   44
# 06               56          56         56   56   56     56   56
# 07               60          60         60   60   60     60   60
# 08               50          50         50   50   50     50   50
# 09               52          52         52   52   52     52   52
# 10               57          57         57   57   57     57   57
# 11               51          51         51   51   51     51   51
# 12               45          45         45   45   45     45   45

# %%
groupby_birthday_employee_df.plot(kind="bar", y="Emp ID", title="Employee Birthdays by Month")
plt.xlabel("Birth Month")
plt.ylabel("Number of Employee Birthdays")
# Out:
# Text(0, 0.5, 'Number of Employee Birthdays')
